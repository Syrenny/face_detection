# %%
SOURCE_VIDEO_PATH = f"data/video/example_3.avi"

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32501MiB)
# Setup complete ✅ (80 CPUs, 754.5 GB RAM, 4002.8/4434.8 GB disk)

# %%
from tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# Unfortunately, we have to manually match the bounding boxes coming from our model with those created by the tracker.

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# settings
MODEL = "weights/yolov8n-face.pt"
# MODEL = "yolov5/runs/train/exp6/weights/best.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# YOLOv8n-pose summary (fused): 187 layers, 3078128 parameters, 0 gradients, 8.3 GFLOPs

# %% [markdown]
# ## Predict and annotate single frame

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [0]

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] non-existing PPS 0 referenced
# [h264 @ 0x5619cc434e40] decode_slice_header error
# [h264 @ 0x5619cc434e40] no frame!
# 0: 416x640 (no detections), 99.0ms
# Speed: 8.6ms preprocess, 99.0ms inference, 18.9ms postprocess per image at shape (1, 3, 416, 640)

# %%
# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink("data/video/output_detect.mp4", video_info) as sink:
    # loop over video frames
    for frame in generator:
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # format custom labels
        labels = [
            f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        sink.write_frame(frame)
# Out:
# 0: 416x640 (no detections), 9.6ms
# Speed: 5.4ms preprocess, 9.6ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e0ba19c0] decode_slice_header error
# [h264 @ 0x5619e0ba19c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] non-existing PPS 0 referenced
# [h264 @ 0x5619e19695c0] decode_slice_header error
# [h264 @ 0x5619e19695c0] no frame!
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 3.4ms preprocess, 7.0ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.2ms
# Speed: 3.5ms preprocess, 7.2ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 4.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 faces, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 462.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.3ms
# Speed: 3.3ms preprocess, 7.3ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.2ms
# Speed: 3.4ms preprocess, 7.2ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.2ms
# Speed: 3.6ms preprocess, 7.2ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.8ms
# Speed: 3.5ms preprocess, 6.8ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.1ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 7.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.1ms preprocess, 6.9ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.8ms preprocess, 7.0ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 2.9ms preprocess, 6.4ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.8ms preprocess, 6.9ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 4.0ms preprocess, 7.0ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.9ms preprocess, 6.9ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.8ms preprocess, 6.9ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.7ms preprocess, 7.0ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.6ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.9ms preprocess, 7.0ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 4.2ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.1ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 3.5ms preprocess, 7.1ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.2ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.2ms preprocess, 7.0ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.6ms preprocess, 7.0ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 3.5ms preprocess, 7.1ms inference, 12.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.2ms
# Speed: 3.8ms preprocess, 7.2ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 3.0ms preprocess, 6.4ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 2.8ms preprocess, 7.1ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.2ms
# Speed: 3.5ms preprocess, 7.2ms inference, 11.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.1ms preprocess, 6.9ms inference, 11.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 3.9ms preprocess, 7.1ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 3.2ms preprocess, 7.1ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 2.9ms preprocess, 7.1ms inference, 12.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 2.8ms preprocess, 7.1ms inference, 11.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 2.9ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.4ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 12.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 3.1ms preprocess, 7.0ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.2ms
# Speed: 2.6ms preprocess, 7.2ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 11.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 2.5ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 3.7ms preprocess, 6.5ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 12.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 11.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.9ms
# Speed: 3.8ms preprocess, 6.9ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.2ms
# ...
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 face, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 3.4ms preprocess, 6.9ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.8ms preprocess, 7.1ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.9ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 4.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 3.7ms preprocess, 7.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 4.0ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 3.8ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 3.4ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.4ms preprocess, 7.1ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 3.7ms preprocess, 6.9ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.3ms
# Speed: 2.7ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 3.8ms preprocess, 6.9ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 3.7ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.6ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 4.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.1ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.7ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 4.0ms preprocess, 6.9ms inference, 4.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 4.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 4.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 6.9ms
# Speed: 3.8ms preprocess, 6.9ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = Point(50, 1500)
LINE_END = Point(3840-50, 1500)

TARGET_VIDEO_PATH = f"data/video/output_test1.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d4a100] decode_slice_header error
# [h264 @ 0x5619e0d4a100] no frame!
# VideoInfo(width=1280, height=800, fps=30, total_frames=602)

# %%
# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)


# create list of dicts for data of faces (final images of faces)
detected_faces = []

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in generator:
        # model prediction on single frame and conversion to supervision Detections
       
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        
        # collecting data for final face images
        for xyxy, confidence, class_id, tracker_id in detections:
            detected_faces.append({'id': tracker_id, 'confidence': confidence, 'image': frame, 'coordinates': xyxy})
            
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        
        
        
        
        
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)
# Out:
# 0: 416x640 (no detections), 7.9ms
# Speed: 3.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d46f00] decode_slice_header error
# [h264 @ 0x5619e0d46f00] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] non-existing PPS 0 referenced
# [h264 @ 0x5619e0d05880] decode_slice_header error
# [h264 @ 0x5619e0d05880] no frame!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 33
#      31 detections.filter(mask=mask, inplace=True)
#      32 # tracking detections
# ---> 33 tracks = byte_tracker.update(
#      34     output_results=detections2boxes(detections=detections),
#      35     img_info=frame.shape,
#      36     img_size=frame.shape
#      37 )
#      38 tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
#      39 detections.tracker_id = np.array(tracker_id)
#
# File /workspace/Syrenny/tracker/byte_tracker.py:207, in BYTETracker.update(self, output_results, img_info, img_size)
#     205 # Predict the current location with KF
#     206 STrack.multi_predict(strack_pool)
# --> 207 dists = matching.iou_distance(strack_pool, detections)
#     208 if not self.args.mot20:
#     209     dists = matching.fuse_score(dists, detections)
#
# File /workspace/Syrenny/tracker/matching.py:88, in iou_distance(atracks, btracks)
#      86     atlbrs = [track.tlbr for track in atracks]
#      87     btlbrs = [track.tlbr for track in btracks]
# ---> 88 _ious = ious(atlbrs, btlbrs)
#      89 cost_matrix = 1 - _ious
#      91 return cost_matrix
#
# File /workspace/Syrenny/tracker/matching.py:61, in ious(atlbrs, btlbrs)
#      53 def ious(atlbrs, btlbrs):
#      54     """
#      55     Compute cost based on IoU
#      56     :type atlbrs: list[tlbr] | np.ndarray
#    (...)
#      59     :rtype ious np.ndarray
#      60     """
# ---> 61     ious = np.zeros((len(atlbrs), len(btlbrs)), dtype=np.float)
#      62     if ious.size == 0:
#      63         return ious
#
# File /workspace/Syrenny/syrenny_venv/lib/python3.10/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ## Getting crops of frames with faces

# %%
from PIL import Image

# %%
def split_by_tracker_id(data_list, key):
    groups = []
    for item in data_list:
        added = False
        for group in groups:
            if item[key] == group[0][key]:
                group.append(item)
                added = True
                break
        if not added:
            groups.append([item])
    return groups


def get_the_best_bbox(groups_by_id):
    result = []
    for group in groups_by_id:
        result.append(max(group, key=lambda x: x['confidence']))
    return result

                      
def crop_images(frames, bbox):
    # Unpack the bounding box coordinates
    x_min, y_min, x_max, y_max = bbox
    # Crop the image using the bounding box coordinates
    #cropped_image = frames.crop((x_min, y_min, x_max, y_max))    
    cropped_image = frames[int(y_min)-5:int(y_max)+5, int(x_min)-5:int(x_max)+5]
    return cropped_image

# split data on goups by tracker id
groups_by_id = split_by_tracker_id(detected_faces, 'id')
# getting the best bbox according to confidence
best_face_images = get_the_best_bbox(groups_by_id)

# list of final images
faces = []
for image in best_face_images:
    faces.append(crop_images(image['image'], image['coordinates']))
    # %matplotlib inline
    show_frame_in_notebook(faces[-1])

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
